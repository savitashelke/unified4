# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
df=pd.read_csv('Amazon Sales data.csv')

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
df.tail()
# Out:
#                 Region       Country      Item Type Sales Channel  \
# 95  Sub-Saharan Africa          Mali        Clothes        Online
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub-Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub-Saharan Africa    Mozambique      Household       Offline
#
#    Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 95              M   7/26/2011  512878119    9/3/2011         888      109.28
# 96              L  11/11/2011  810711038  12/28/2011        6267        9.33
# 97              C    6/1/2016  728815257   6/29/2016        1485      154.06
# 98              M   7/30/2015  559427106    8/8/2015        5767       81.73
# 99              L   2/10/2012  665095412   2/15/2012        5367      668.27
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.shape
# Out:
# (100, 14)

# %%
df=df.drop(columns="Order ID",axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Ship Date       100 non-null    object
#  7   Units Sold      100 non-null    int64
#  8   Unit Price      100 non-null    float64
#  9   Unit Cost       100 non-null    float64
#  10  Total Revenue   100 non-null    float64
#  11  Total Cost      100 non-null    float64
#  12  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 10.3+ KB

# %%
df['Order Priority'].value_counts()
# Out:
# H    30
# L    27
# C    22
# M    21
# Name: Order Priority, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                   36
# Europe                               22
# Australia and Oceania                11
# Asia                                 11
# Middle East and North Africa         10
# Central America and the Caribbean     7
# North America                         3
# Name: Region, dtype: int64

# %%
df.describe()
# Out:
#         Units Sold  Unit Price   Unit Cost  Total Revenue    Total Cost  \
# count   100.000000  100.000000  100.000000   1.000000e+02  1.000000e+02
# mean   5128.710000  276.761300  191.048000   1.373488e+06  9.318057e+05
# std    2794.484562  235.592241  188.208181   1.460029e+06  1.083938e+06
# min     124.000000    9.330000    6.920000   4.870260e+03  3.612240e+03
# 25%    2836.250000   81.730000   35.840000   2.687212e+05  1.688680e+05
# 50%    5382.500000  179.880000  107.275000   7.523144e+05  3.635664e+05
# 75%    7369.000000  437.200000  263.330000   2.212045e+06  1.613870e+06
# max    9925.000000  668.270000  524.960000   5.997055e+06  4.509794e+06
#
#        Total Profit
# count  1.000000e+02
# mean   4.416820e+05
# std    4.385379e+05
# min    1.258020e+03
# 25%    1.214436e+05
# 50%    2.907680e+05
# 75%    6.358288e+05
# max    1.719922e+06

# %%
df.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
file_name='C.xlsx'

# %%
df.to_excel(file_name)

# %%
total_Profit=df['Total Profit'].sum()
print('Total Profit:',total_Profit)
total_Revenue=df['Total Revenue'].sum()
print('Total Revenue:',total_Revenue)
# Out:
# Total Profit: 44168198.39999999
# Total Revenue: 137348768.31

# %% [markdown]
# # visualisation of data

# %%
plt.figure(figsize=(14,6))
plt.title("Total Profit & Total Cost")
sns.lineplot(data=df['Total Profit'],label='Total Profit')
sns.lineplot(data=df['Total Cost'],label='Total Cost')
# Out:
# <AxesSubplot:title={'center':'Total Profit & Total Cost'}, ylabel='Total Profit'>

# %%
percentage=[]
for i in range(df.shape[0]):
    pct=(df['Total Profit'][i]/total_Revenue)*100
    percentage.append(round(pct,2))
print(percentage)
df['percentage']=percentage
display(df)
# Out:
# [0.69, 0.18, 0.16, 0.01, 0.47, 0.21, 0.51, 0.37, 0.11, 0.43, 0.01, 0.22, 0.44, 1.08, 0.09, 0.09, 0.88, 0.06, 0.46, 0.25, 0.52, 0.09, 0.09, 0.0, 0.09, 0.23, 0.01, 0.01, 0.06, 0.29, 1.1, 0.04, 0.27, 1.0, 0.29, 0.12, 0.01, 0.2, 0.62, 0.37, 0.06, 0.92, 0.14, 0.01, 0.32, 0.06, 1.12, 0.0, 0.42, 0.12, 0.12, 0.02, 0.26, 0.32, 0.01, 0.19, 0.53, 0.36, 0.03, 0.91, 0.04, 0.33, 0.51, 0.33, 0.22, 0.57, 0.16, 0.29, 0.76, 0.39, 0.46, 0.0, 0.07, 0.56, 1.25, 0.84, 0.11, 0.17, 0.6, 1.22, 0.54, 0.42, 0.82, 0.16, 0.3, 0.12, 0.1, 0.39, 0.0, 0.05, 0.09, 0.11, 0.19, 1.0, 0.09, 0.05, 0.01, 0.07, 0.11, 0.65]
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# ...

# %%
plt.figure(figsize=(20, 20))
colors_list = ['Red', 'Green','Orange' ,'Purple','blue','yellow','pink']
graph = plt.bar(df['Region'], df['Total Profit'], color=colors_list)
plt.title('Percentage across of all formats')

i = 0
for p in graph:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
     
    plt.text(x+width/2,
             y+height*1.01,
             str(df.percentage[i])+'%',
             ha='center',
             weight='bold')
    i += 1
plt.show()

# %%
plt.figure(figsize=(16,7))
sns.barplot(x=df['Item Type'], y=df['Total Profit'])
plt.title("Which item is best for Profit",size=20)
# Out:
# Text(0.5, 1.0, 'Which item is best for Profit')

# %%
plt.figure(figsize=(16,7))
sns.barplot(x=df['Item Type'], y=df['Total Cost'])
plt.title("Which item is less Costly",size=20)
# Out:
# Text(0.5, 1.0, 'Which item is less Costly')

# %%
plt.figure(figsize=(16,7))
sns.barplot(x=df['Region'], y=df['Total Profit'])
plt.title('Which region is best for Profit',size=20)
# Out:
# Text(0.5, 1.0, 'Which region is best for Profit')

# %%
plt.figure(figsize=(16,7))
sns.barplot(x=df['Region'], y=df['Total Cost'])
plt.title("Which region is less Costly",size=20)
# Out:
# Text(0.5, 1.0, 'Which region is less Costly')

# %%
plt.figure(figsize=(16,7))
sns.barplot(x=df['Sales Channel'], y=df['Total Profit'])
plt.title("Which Sales_Channel is best for the Profit",size=20)
# Out:
# Text(0.5, 1.0, 'Which Sales_Channel is best for the Profit')

# %%
plt.figure(figsize=(16,7))
sns.barplot(x=df['Order Priority'], y=df['Total Profit'])
# Out:
# <AxesSubplot:xlabel='Order Priority', ylabel='Total Profit'>

# %%
plt.figure(figsize=(16,7))
sns.barplot(x=df['Sales Channel'], y=df['Total Cost'])
plt.title("Which Sales_Channel is Costly",size=20)
# Out:
# Text(0.5, 1.0, 'Which Sales_Channel is Costly')

# %%
sns.pairplot(df,hue='Sales Channel')

# %%
sns.pairplot(df,hue='Order Priority')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data=df,x='Total Profit',hue='Sales Channel')
# Out:
# <AxesSubplot:xlabel='Total Profit', ylabel='Count'>

# %%
sns.histplot(data=df,x='Total Cost',hue='Sales Channel')
# Out:
# <AxesSubplot:xlabel='Total Cost', ylabel='Count'>

# %%
sns.kdeplot(data=df, x="Total Profit", hue="Sales Channel", multiple="stack")
# Out:
# <AxesSubplot:xlabel='Total Profit', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="Total Cost", hue="Sales Channel", multiple="stack")
# Out:
# <AxesSubplot:xlabel='Total Cost', ylabel='Density'>

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(x=df['Total Profit'], y=df['Total Cost'], hue=df['Item Type'])
# Out:
# <AxesSubplot:xlabel='Total Profit', ylabel='Total Cost'>

# %%
df['Total Profit'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Total Cost'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df[['Order day', 'Order month', 'Order Date']] = df['Order Date'].str.split('/', expand=True)

# %%
df[['Order day', 'Order month', 'Order Date']]=df[['Order day', 'Order month', 'Order Date']]

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date  Ship Date  Units Sold  Unit Price  \
# 0       Offline              H       2010  6/27/2010        9925      255.28
# 1        Online              C       2012  9/15/2012        2804      205.70
# 2       Offline              L       2014   5/8/2014        1779      651.21
# 3        Online              C       2014   7/5/2014        8102        9.33
# 4       Offline              L       2013   2/6/2013        5062      651.21
#
# ...

# %%
sns.histplot(data=df,x='Order Date',y='Total Profit',hue="Sales Channel")
# Out:
# <AxesSubplot:xlabel='Order Date', ylabel='Total Profit'>

# %%
sns.histplot(data=df,x='Order Date',y='Total Cost',hue="Sales Channel")
# Out:
# <AxesSubplot:xlabel='Order Date', ylabel='Total Cost'>

# %%
plt.figure(figsize=(16,7))
sns.barplot(x=df['Order Date'], y=df['Total Cost'])
plt.title('Which year had less costly',size=(20.6))
# Out:
# Text(0.5, 1.0, 'Which year had less costly')

# %%
plt.figure(figsize=(16,7))
sns.barplot(x=df['Order Date'], y=df['Total Profit'])
plt.title('Which year had more profit',size=(20.6))
# Out:
# Text(0.5, 1.0, 'Which year had more profit')
